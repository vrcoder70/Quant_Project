# %% [markdown]
# ### 1. Load Twitter Sentiment Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import yfinance as yf
import os
import datetime as dt
import warnings

warnings.filterwarnings('ignore')
plt.style.use('ggplot')

# %%
twt_sent_df = pd.read_csv('sentiment_data.csv')
twt_sent_df['date'] = pd.to_datetime(twt_sent_df['date'])
twt_sent_df.set_index(['date','symbol'], inplace=True)
twt_sent_df['engagementRatio'] = twt_sent_df['twitterComments']/twt_sent_df['twitterLikes'] # Change Formula to get better result
twt_sent_df = twt_sent_df[(twt_sent_df['twitterLikes']>20) & (twt_sent_df['twitterComments']>10)]
twt_sent_df
# Out:
#                    twitterPosts  twitterComments  twitterLikes  \
# date       symbol
# 2021-11-18 AAPL           811.0           2592.0       21674.0
#            AMD            150.0            675.0        2949.0
#            AMZN           557.0           1315.0       12969.0
#            ATVI            82.0             36.0         131.0
#            BA              61.0             55.0         342.0
# ...                         ...              ...           ...
# 2023-01-04 T              184.0           3409.0       14271.0
#            TSLA          6767.0         540711.0     3810688.0
#            TSN             35.0            168.0         460.0
#            V              132.0           1008.0        5943.0
#            XOM            212.0            374.0        2071.0
#
#                    twitterImpressions  twitterSentiment  engagementRatio
# date       symbol
# 2021-11-18 AAPL             7981808.0               NaN         0.119590
# ...

# %% [markdown]
# ### 2. Aggregate Monthly and calculate average sentiment for the month

# %%
agg_df = twt_sent_df.reset_index('symbol').groupby([pd.Grouper(freq ='M'), 'symbol'])[['engagementRatio']].mean()

agg_df['rank'] = agg_df.groupby(level=0)['engagementRatio'].transform(lambda x: x.rank(ascending=False))

agg_df
# Out:
#                    engagementRatio  rank
# date       symbol
# 2021-11-30 AAL            0.203835  37.0
#            AAPL           0.256318  23.0
#            ABBV           0.244677  26.0
#            ABT            0.313368  14.0
#            AES            0.864613   2.0
# ...                            ...   ...
# 2023-01-31 TMO            0.333313  19.0
#            TSLA           0.151992  72.0
#            TSN            0.280553  30.0
#            V              0.194045  60.0
#            XOM            0.217904  53.0
#
# [1109 rows x 2 columns]

# %% [markdown]
# ### 3. Select Top 5 Stocks based on their cross-sectional ranking for each month

# %%
filter_df = agg_df[agg_df['rank']<6].copy()

filter_df.reset_index(level=1, inplace=True)

filter_df.index = filter_df.index + pd.DateOffset(1)

filter_df = filter_df.reset_index().set_index(['date','symbol'])

filter_df.head(20)
# Out:
#                    engagementRatio  rank
# date       symbol
# 2021-12-01 AES            0.864613   2.0
#            FCX            0.626323   5.0
#            MNST           0.699721   3.0
#            OXY            2.147741   1.0
#            SLB            0.647374   4.0
# 2022-01-01 D              0.801994   5.0
#            FCX            0.841220   4.0
#            L              6.507246   1.0
#            LUV            1.303215   2.0
#            MA             0.883401   3.0
# 2022-02-01 AMD            0.715556   4.0
#            D              1.136678   1.0
#            FCX            0.655237   5.0
#            LUV            1.035258   2.0
#            MA             0.729063   3.0
# 2022-03-01 FCX            1.138332   2.0
#            GILD           0.530886   5.0
#            LUV            1.574377   1.0
#            MRO            0.581748   4.0
#            OXY            1.025579   3.0

# %% [markdown]
# ### 4. Extract the stocks to form portfolios with at the start of each new month

# %%
dates = filter_df.index.get_level_values('date').unique().tolist()

fixed_dates = {}

for d in dates:
    fixed_dates[d.strftime('%Y-%m-%d')] = filter_df.xs(d, level=0).index.tolist()

fixed_dates
# Out:
# {'2021-12-01': ['AES', 'FCX', 'MNST', 'OXY', 'SLB'],
#  '2022-01-01': ['D', 'FCX', 'L', 'LUV', 'MA'],
#  '2022-02-01': ['AMD', 'D', 'FCX', 'LUV', 'MA'],
#  '2022-03-01': ['FCX', 'GILD', 'LUV', 'MRO', 'OXY'],
#  '2022-04-01': ['A', 'CRM', 'PFE', 'PM', 'STZ'],
#  '2022-05-01': ['AMD', 'CRM', 'CVX', 'J', 'KEY'],
#  '2022-06-01': ['AMD', 'DD', 'FCX', 'KEY', 'LMT'],
#  '2022-07-01': ['CB', 'CRM', 'DD', 'FCX', 'STZ'],
#  '2022-08-01': ['A', 'DD', 'JPM', 'REGN', 'STZ'],
#  '2022-09-01': ['ABT', 'DIS', 'L', 'META', 'MRNA'],
#  '2022-10-01': ['J', 'KEY', 'L', 'META', 'MU'],
#  '2022-11-01': ['A', 'DD', 'FCX', 'J', 'META'],
#  '2022-12-01': ['AEP', 'AES', 'DD', 'J', 'STZ'],
#  '2023-01-01': ['A', 'AES', 'DAL', 'J', 'KEY'],
#  '2023-02-01': ['A', 'AES', 'BIIB', 'FCX', 'MDT']}

# %% [markdown]
# ### 5. Download fresh stock prices for only selected/shortlisted stocks

# %%
stock_list = filter_df.index.get_level_values('symbol').unique().tolist()

price_df = yf.download(tickers=stock_list, start='2021-01-01', end='2024-01-01')
# Out:
# [*********************100%%**********************]  34 of 34 completed

# %% [markdown]
# ### 6. Calculate Portfolio Returns with monthly rebalancing

# %%
returns_df = np.log(price_df['Adj Close']).diff().dropna()

portfolio_df = pd.DataFrame()

for start_date in fixed_dates.keys():
    
    end_date = (pd.to_datetime(start_date)+pd.offsets.MonthEnd()).strftime('%Y-%m-%d')
    
    cols = fixed_dates[start_date]
    
    temp_df = returns_df[start_date:end_date][cols].mean(axis=1).to_frame('portfolio_return')
    
    portfolio_df = pd.concat([portfolio_df, temp_df], axis=0)
    
portfolio_df
# Out:
#             portfolio_return
# Date
# 2021-12-01         -0.016417
# 2021-12-02          0.024872
# 2021-12-03         -0.007711
# 2021-12-06          0.023926
# 2021-12-07          0.030547
# ...                      ...
# 2023-02-22         -0.007870
# 2023-02-23         -0.007323
# 2023-02-24         -0.009463
# 2023-02-27         -0.001871
# 2023-02-28          0.001403
#
# [312 rows x 1 columns]

# %% [markdown]
# ### 7. Download NASDAQ/QQQ prices and calculate returns to compare to our strategy

# %%
qqq_df = yf.download(tickers='QQQ',
                     start='2021-01-01',
                     end='2024-01-01')

qqq_ret = np.log(qqq_df['Adj Close']).diff().to_frame('nasdaq_return')

portfolio_df = portfolio_df.merge(qqq_ret,
                                  left_index=True,
                                  right_index=True)

portfolio_df
# Out:
# [*********************100%%**********************]  1 of 1 completed
#             portfolio_return  nasdaq_return_x  nasdaq_return_y
# Date
# 2021-12-01         -0.016417        -0.017159        -0.017159
# 2021-12-02          0.024872         0.007181         0.007181
# 2021-12-03         -0.007711        -0.017542        -0.017542
# 2021-12-06          0.023926         0.007981         0.007981
# 2021-12-07          0.030547         0.029669         0.029669
# ...                      ...              ...              ...
# 2023-02-22         -0.007870         0.000748         0.000748
# 2023-02-23         -0.007323         0.008696         0.008696
# 2023-02-24         -0.009463        -0.016886        -0.016886
# 2023-02-27         -0.001871         0.007136         0.007136
# 2023-02-28          0.001403        -0.001294        -0.001294
#
# [312 rows x 3 columns]

# %%
portfolios_cumulative_return = np.exp(np.log1p(portfolio_df).cumsum()).sub(1)

portfolios_cumulative_return.plot(figsize=(16,6))

plt.title('Twitter Engagement Ratio Strategy Return Over Time')

plt.gca().yaxis.set_major_formatter(mtick.PercentFormatter(1))

plt.ylabel('Return')

plt.show()
